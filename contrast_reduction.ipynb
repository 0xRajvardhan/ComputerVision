# %%
import cv2
from matplotlib import pyplot as plt
import PIL as pillow
import numpy as np

# %%
image = cv2.imread('./images/contrast.jpg')
plt.imshow(image)

# %%
images = cv2.bitwise_not(image)
plt.imshow(images)
cv2.imwrite('./images/contrast_output.jpg', images)
# Out:
# True

# %%
from PIL import Image
from numpy import array
img_1 = Image.open('./images/contrast.jpg')
arr_1 = array(img_1)
arr_1

img_2 = Image.open('./images/contrast_output.jpg')
arr_2 = array(img_2)
arr_2
# Out:
# array([[[199, 170, 126],
#         [184, 153, 107],
#         [180, 142,  93],
#         ...,
#         [205, 198, 169],
#         [181, 181, 153],
#         [230, 235, 205]],
#
#        [[187, 158, 116],
#         [204, 172, 131],
#         [213, 181, 142],
#         ...,
#         [180, 170, 135],
#         [205, 201, 166],
#         [229, 226, 191]],
#
#        [[228, 196, 158],
#         [244, 215, 185],
#         [252, 229, 211],
#         ...,
#         [219, 200, 157],
#         [216, 199, 153],
#         [159, 145,  98]],
#
#        ...,
#
#        [[231, 216, 239],
#         [232, 217, 240],
#         [227, 212, 235],
#         ...,
#         [241, 230, 246],
#         [238, 225, 242],
#         [236, 223, 241]],
#
#        [[223, 207, 233],
#         [225, 209, 235],
#         [222, 206, 232],
#         ...,
#         [234, 223, 237],
#         [234, 221, 238],
#         [238, 225, 242]],
#
#        [[225, 209, 236],
#         [227, 211, 238],
#         [224, 208, 235],
# ...
